# %% [markdown]
# # Test Preprocessing Pipeline

# %%
import sys
from pathlib import Path

# Add parent directory to path
sys.path.insert(0, str(Path.cwd()))

print("✓ Path setup complete")
# Out:
# ✓ Path setup complete

# %% [markdown]
# ## Test 1: Import Preprocessing Module

# %%
from preprocessing import FeatureExtractor, DatasetPreprocessor
from preprocessing import VITONHDDataset, DressCodeDataset, DatasetValidator, get_dataset_loader

print("✓ All imports successful")
print("✓ FeatureExtractor: Available")
print("✓ DatasetPreprocessor: Available")
print("✓ VITONHDDataset: Available")
print("✓ DressCodeDataset: Available")
print("✓ DatasetValidator: Available")
print("✓ get_dataset_loader: Available")
# Out:
# ✓ All imports successful
# ✓ FeatureExtractor: Available
# ✓ DatasetPreprocessor: Available
# ✓ VITONHDDataset: Available
# ✓ DressCodeDataset: Available
# ✓ DatasetValidator: Available
# ✓ get_dataset_loader: Available

# %% [markdown]
# ## Test 2: Initialize FeatureExtractor

# %%
try:
    extractor = FeatureExtractor(gpu_id=0, device='cuda:0')
    print("✓ FeatureExtractor initialized successfully")
    print(f"  GPU ID: 0")
    print(f"  Device: cuda:0")
except Exception as e:
    print(f"✗ Error initializing FeatureExtractor: {e}")
    print("  Note: This is expected if GPU/models are not available")
# Out:
# 2025-11-14 13:35:28.849782001 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431021, index: 1, mask: {2, 82, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.849829370 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431022, index: 2, mask: {3, 83, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.849778326 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431020, index: 0, mask: {1, 81, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.849821059 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431023, index: 3, mask: {4, 84, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.849930931 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431024, index: 4, mask: {5, 85, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.849942574 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431025, index: 5, mask: {6, 86, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.849976059 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431026, index: 6, mask: {7, 87, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850021037 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431027, index: 7, mask: {8, 88, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850040234 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431028, index: 8, mask: {9, 89, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850081373 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431029, index: 9, mask: {10, 90, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850118840 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431030, index: 10, mask: {11, 91, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850132134 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431031, index: 11, mask: {12, 92, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850197456 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431032, index: 12, mask: {13, 93, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850230851 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431033, index: 13, mask: {14, 94, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850239048 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431034, index: 14, mask: {15, 95, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850273879 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431035, index: 15, mask: {16, 96, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850292159 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431036, index: 16, mask: {17, 97, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850319698 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431037, index: 17, mask: {18, 98, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850340372 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431038, index: 18, mask: {19, 99, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850375177 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431039, index: 19, mask: {20, 100, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850397413 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431040, index: 20, mask: {21, 101, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850419824 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431041, index: 21, mask: {22, 102, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850446740 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431042, index: 22, mask: {23, 103, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850473833 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431043, index: 23, mask: {24, 104, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850506561 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431044, index: 24, mask: {25, 105, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850530643 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431045, index: 25, mask: {26, 106, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850560394 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431046, index: 26, mask: {27, 107, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850589911 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431047, index: 27, mask: {28, 108, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850612297 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431048, index: 28, mask: {29, 109, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850647935 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431049, index: 29, mask: {30, 110, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.850664590 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431050, index: 30, mask: {31, 111, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.851752797 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431052, index: 32, mask: {33, 113, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.858979803 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431053, index: 33, mask: {34, 114, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.869961465 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431092, index: 72, mask: {73, 153, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:28.869987833 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 
[E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431132, index: 33, mask: {34, 114, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.932961803 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431133, index: 34, mask: {35, 115, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.933962302 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431136, index: 37, mask: {38, 118, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.937967237 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431135, index: 36, mask: {37, 117, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.929961826 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431134, index: 35, mask: {36, 116, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.929962176 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431131, index: 32, mask: {33, 113, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.950968894 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431156, index: 57, mask: {58, 138, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.950985699 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431154, index: 55, mask: {56, 136, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.950998246 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431173, index: 74, mask: {75, 155, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.951011436 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431165, index: 66, mask: {67, 147, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.951023207 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431159, index: 60, mask: {61, 141, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.951193456 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431171, index: 72, mask: {73, 153, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.951204628 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431175, index: 76, mask: {77, 157, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.951215033 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431160, index: 61, mask: {62, 142, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.951227811 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431157, index: 58, mask: {59, 139, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.951263810 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431177, index: 78, mask: {79, 159, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.951313152 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431161, index: 62, mask: {63, 143, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.951368516 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431167, index: 68, mask: {69, 149, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.963980806 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431168, index: 69, mask: {70, 150, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.964010095 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431176, index: 77, mask: {78, 158, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.938117138 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431155, index: 56, mask: {57, 137, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.951035969 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431162, index: 63, mask: {64, 144, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.951239844 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431164, index: 65, mask: {66, 146, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.963991094 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431174, index: 75, mask: {76, 156, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.951353958 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431166, index: 67, mask: {68, 148, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.951297029 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431158, index: 59, mask: {60, 140, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.976996466 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431172, index: 73, mask: {74, 154, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.976985619 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431170, index: 71, mask: {72, 152, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.976975656 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431169, index: 70, mask: {71, 151, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:29.986133466 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431163, index: 64, mask: {65, 145, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# /scratch/yp2693/CV_project/IDM-VTON/preprocess/openpose/annotator/openpose/body.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_dict = util.transfer(self.model, torch.load(model_path))
# ✓ FeatureExtractor initialized successfully
#   GPU ID: 0
#   Device: cuda:0

# %% [markdown]
# ## Test 3: Check FeatureExtractor Methods

# %%
try:
    methods = [
        'extract_keypoints',
        'extract_parsing',
        'generate_mask',
        'extract_pose_image',
        'prepare_garment_tensor',
        'process'
    ]
    
    for method in methods:
        if hasattr(extractor, method):
            print(f"✓ {method}")
        else:
            print(f"✗ {method} - NOT FOUND")
except NameError:
    print("Note: Extractor not initialized, skipping method check")
# Out:
# ✓ extract_keypoints
# ✓ extract_parsing
# ✓ generate_mask
# ✓ extract_pose_image
# ✓ prepare_garment_tensor
# ✓ process

# %% [markdown]
# ## Test 4: Check DatasetPreprocessor

# %%
try:
    preprocessor = DatasetPreprocessor(gpu_id=0, device='cuda:0')
    print("✓ DatasetPreprocessor initialized")
    
    methods = ['preprocess_viton_hd', 'preprocess_dresscode']
    for method in methods:
        if hasattr(preprocessor, method):
            print(f"✓ {method}")
        else:
            print(f"✗ {method} - NOT FOUND")
except Exception as e:
    print(f"✗ Error: {e}")
    print("  Note: This is expected if GPU/models are not available")
# Out:
# 2025-11-14 13:35:43.127709407 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431290, index: 0, mask: {1, 81, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:43.127728886 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431291, index: 1, mask: {2, 82, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:43.127747163 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431292, index: 2, mask: {3, 83, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:43.127769866 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 431293, index: 3, mask: {4, 84, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-11-14 13:35:43.127789803 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 
}, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# ✓ DatasetPreprocessor initialized
# ✓ preprocess_viton_hd
# ✓ preprocess_dresscode

# %% [markdown]
# ## Test 5: Check Dataset Classes

# %%
print("Dataset Classes:")
print(f"✓ VITONHDDataset: {VITONHDDataset.__name__}")
print(f"✓ DressCodeDataset: {DressCodeDataset.__name__}")
print(f"✓ DatasetValidator: {DatasetValidator.__name__}")
print(f"✓ get_dataset_loader: {get_dataset_loader.__name__}")
# Out:
# Dataset Classes:
# ✓ VITONHDDataset: VITONHDDataset
# ✓ DressCodeDataset: DressCodeDataset
# ✓ DatasetValidator: DatasetValidator
# ✓ get_dataset_loader: get_dataset_loader

# %% [markdown]
# ## Test 6: Test with Sample Image

# %%
from PIL import Image
import numpy as np

# Create dummy images for testing
human_img = Image.open('test_assets/human/xxl_men.png').convert('RGB')
garment_img = Image.open('test_assets/garment/3.png').convert('RGB')

print("✓ Test images created")
print(f"  Human image: {human_img.size}")
print(f"  Garment image: {garment_img.size}")
# Out:
# ✓ Test images created
#   Human image: (360, 360)
#   Garment image: (2000, 2500)

# %% [markdown]
# ## Test 7: Test Feature Extraction (if GPU available)

# %%
try:
    print("Testing feature extraction...")
    output = extractor.process(human_img, garment_img)
    
    print("✓ Feature extraction successful")
    print(f"  Human image: {output.human_image.size}")
    print(f"  Garment image: {output.garment_image.size}")
    print(f"  Pose image: {output.pose_image.size}")
    print(f"  Inpaint mask: {output.inpaint_mask.size}")
    print(f"  Keypoints detected: {len(output.human_keypoints.get('pose_keypoints_2d', []))}")
    print(f"  Keypoints: {output.human_keypoints}")

    # Save all features to images
    output.human_image.save("feature_human_image.png")
    output.garment_image.save("feature_garment_image.png")
    output.pose_image.save("feature_pose_image.png")
    output.inpaint_mask.save("feature_inpaint_mask.png")
    print("✓ Saved feature images: feature_human_image.png, feature_garment_image.png, feature_pose_image.png, feature_inpaint_mask.png")
    # Optionally save keypoints as a .npy or .json if needed
    import json
    with open("feature_human_keypoints.json", "w") as f:
        json.dump(output.human_keypoints, f)
    print("✓ Saved keypoints: feature_human_keypoints.json")
    print(f"  Category: {output.category}")
except NameError:
    print("Note: Extractor not initialized")
except Exception as e:
    print(f"Note: {type(e).__name__}: {e}")
    print("This is expected if models/GPU are not available")
# Out:
# Testing feature extraction...
# 100%|██████████| 1/1 [00:01<00:00,  1.91s/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.80s/it]
# ✓ Feature extraction successful
#   Human image: (768, 1024)
#   Garment image: (768, 1024)
#   Pose image: (768, 1024)
#   Inpaint mask: (384, 512)
#   Keypoints detected: 18
#   Keypoints: {'pose_keypoints_2d': [[190.0, 80.0], [196.0, 156.0], [123.0, 153.0], [63.0, 255.0], [77.0, 364.0], [270.0, 157.0], [321.0, 256.0], [301.0, 359.0], [139.0, 413.0], [0, 0], [0, 0], [243.0, 417.0], [0, 0], [0, 0], [176.0, 69.0], [204.0, 68.0], [160.0, 79.0], [227.0, 77.0]]}
# ✓ Saved feature images: feature_human_image.png, feature_garment_image.png, feature_pose_image.png, feature_inpaint_mask.png
# ✓ Saved keypoints: feature_human_keypoints.json
#   Category: upper_body

# %% [markdown]
# ## Test 8: Test Dataset Validation Setup

# %%
from pathlib import Path

# Check if test datasets exist
viton_hd_path = Path('/path/to/VITON-HD')
dresscode_path = Path('/path/to/DressCode')

print("Dataset paths to test:")
print(f"  VITON-HD: {viton_hd_path}")
print(f"  DressCode: {dresscode_path}")
print()
print("To validate real datasets:")
print("  validator = DatasetValidator()")
print("  results = validator.validate_viton_hd('/path/to/VITON-HD')")
print("  results = validator.validate_dresscode('/path/to/DressCode')")

# %% [markdown]
# ## Test 9: Test DataLoader Creation

# %%
print("To create DataLoader for training:")
print()
print("from preprocessing import get_dataset_loader")
print()
print("# VITON-HD")
print("loader = get_dataset_loader(")
print("    'viton-hd',")
print("    '/path/to/preprocessed',")
print("    batch_size=8,")
print("    num_workers=4")
print(")")
print()
print("# DressCode")
print("loader = get_dataset_loader(")
print("    'dresscode',")
print("    '/path/to/preprocessed',")
print("    category='upper_body',")
print("    batch_size=8")
print(")")
print()
print("for batch in loader:")
print("    human = batch['human']")
print("    garment = batch['garment']")
print("    pose = batch['pose']")
print("    mask = batch['mask']")

# %% [markdown]
# ## Test 10: Test Batch Processing

# %%
print("To preprocess entire dataset:")
print()
print("from preprocessing import DatasetPreprocessor")
print()
print("pp = DatasetPreprocessor(gpu_id=0)")
print()
print("# VITON-HD")
print("pp.preprocess_viton_hd('/input/VITON-HD', '/output')")
print()
print("# DressCode")
print("pp.preprocess_dresscode(")
print("    '/input/DressCode',")
print("    '/output',")
print("    categories=['upper_body', 'lower_body', 'dresses']")
print(")")

# %% [markdown]
# ## Test 11: Module Structure

# %%
import preprocessing
import inspect

print("Preprocessing module contents:")
print()
print("Classes:")
classes = [name for name, obj in inspect.getmembers(preprocessing) 
           if inspect.isclass(obj) and not name.startswith('_')]
for cls in classes:
    print(f"  • {cls}")

print()
print("Functions:")
functions = [name for name, obj in inspect.getmembers(preprocessing) 
             if inspect.isfunction(obj) and not name.startswith('_')]
for func in functions:
    print(f"  • {func}")

# %% [markdown]
# ## Summary

# %%
print("="*60)
print("PREPROCESSING PIPELINE TEST SUMMARY")
print("="*60)
print()
print("✓ Module imports working")
print("✓ All classes available")
print("✓ All functions available")
print()
print("Core components:")
print("  • FeatureExtractor - Extract keypoints, parsing, masks, poses")
print("  • DatasetPreprocessor - Batch process datasets")
print("  • VITONHDDataset - Load VITON-HD data")
print("  • DressCodeDataset - Load DressCode data")
print("  • DatasetValidator - Validate dataset structure")
print("  • get_dataset_loader() - Create DataLoader")
print()
print("Ready to use for:")
print("  • Single image preprocessing")
print("  • Batch dataset preprocessing")
print("  • Training with PyTorch DataLoader")
print("  • Dataset validation")
print()
print("="*60)
